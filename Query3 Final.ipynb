# %%
from sedona.spark import *
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import col, regexp_replace, when, isnull, isnan, sum, count, upper, round
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
import time

spark = SparkSession.builder \
    .appName("Query 3") \
    .getOrCreate()

sedona = SedonaContext.create(spark)

blocks_path = "s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson"
income_path = "s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv"

blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(blocks_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")

blocks_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type")
# κραταμε μονο τις στηλες που μας ενδιαφερουν και τις γραμμες εκεινες
# που εχουν να κανουν με τον δημο του Los Angeles
blocks_df = blocks_df.select("CITY", "COMM", "HOUSING10", "POP_2010")
blocks_df = blocks_df.filter(col("CITY").contains("Los Angeles"))
# υπαρχουν περιοχες που περιεχουν παραπανω απο ενα ZIP code οποτε κανουμε
# goupby με βαση τη καθε περιοχη και προσθετουμε τους επιμερους πληθυσμους
# και τα επιμερους νοικοκυρια
df1 = blocks_df.groupBy("COMM") \
                .agg(sum("POP_2010").alias("total_population"),
                     sum("HOUSING10").alias("number_of_houses"))
# διαβαζουμε το csv με το μεσο εισοδημα ανα νοικοκυριο και κραταμε
# μονο τις στηλες που μας ενδιαφερουν και μονο τις περιπτωσεις
# εκεινες οπου η περιοχη ανηκει στον δημο του Los Angeles
df2 = spark.read.csv(income_path, header=True, inferSchema=True)
df2 = df2.select("Community", "Estimated Median Income")
df2 = df2.filter(col("Community").contains("Los Angeles"))
# αφαιρουμε το συμβολο του δολαριου απο την στηλη με το εισοδημα
# και μετατρεπουμε τον τυπο σε int
df2 = df2.withColumn("int_income",
                     regexp_replace(col("Estimated Median Income"),
                                    r"[$,]", "").cast(IntegerType()))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# κανουμε join υπο την συνθηκη οτι το περιεχομενο του COMM του
# ενος συνολου δεδομενων να περιεχεται στην στηλη Community του
# αλλου συνολου, ετσι ωστε να εχουμε κοινες περιοχες
start_time = time.time()
df = df1.hint("broadcast").join(df2, df2.Community.contains(df1.COMM), "inner")
df.show()
df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Broadcast Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# |           COMM|total_population|number_of_houses|           Community|Estimated Median Income|int_income|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# |          Watts|           39657|            9802|Los Angeles (Sout...|                $30,413|     30413|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $40,612|     40612|
# |   Hancock Park|           15557|            6653|Los Angeles (Hanc...|                $40,612|     40612|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $31,142|     31142|
# |      Koreatown|           48275|           19863|Los Angeles (Hanc...|                $31,142|     31142|
# |   Hancock Park|           15557|            6653|Los Angeles (Hanc...|                $31,142|     31142|
# |      Koreatown|           48275|           19863|Los Angeles (Byza...|                $31,521|     31521|
# |Harvard Heights|           16951|            5199|Los Angeles (Byza...|                $31,521|     31521|
# |  Baldwin Hills|           28637|           13353|Los Angeles (Bald...|                $36,564|     36564|
# |   Leimert Park|           14859|            6469|Los Angeles (Bald...|                $36,564|     36564|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $45,786|     45786|
# |   Hancock Park|           15557|            6653|Los Angeles (Hanc...|                $45,786|     45786|
# |      Chinatown|            7677|            3418|Los Angeles (Down...|                $31,576|     31576|
# |       Downtown|           23647|           17103|Los Angeles (Down...|                $31,576|     31576|
# |   Little Tokyo|            3386|            2077|Los Angeles (Down...|                $31,576|     31576|
# |        Central|           35422|            8174|Los Angeles (Down...|                $19,887|     19887|
# |       Downtown|           23647|           17103|Los Angeles (Down...|                $19,887|     19887|
# |       Downtown|           23647|           17103|Los Angeles (Down...|                $23,642|     23642|
# |     South Park|           35404|            8612|Los Angeles (Dowt...|                $29,684|     29684|
# |     West Adams|           26543|            9373|Los Angeles (West...|                $38,330|     38330|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (14)
# +- BroadcastNestedLoopJoin Inner BuildLeft (13)
#    :- BroadcastExchange (9)
#    :  +- HashAggregate (8)
#    :     +- Exchange (7)
#    :        +- HashAggregate (6)
#    :           +- Project (5)
#    :              +- Filter (4)
#    :                 +- Generate (3)
#    :                    +- Filter (2)
#    :                       +- Scan geojson  (1)
#    +- Project (12)
#       +- Filter (11)
#          +- Scan csv  (10)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6454, features#6438.properties.HOUSING10 AS HOUSING10#6460L, features#6438.properties.POP_2010 AS POP_2010#6463L]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [3]: [COMM#6454, HOUSING10#6460L, POP_2010#6463L]
# Keys [1]: [COMM#6454]
# Functions [2]: [partial_sum(POP_2010#6463L), partial_sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum#6651L, sum#6653L]
# Results [3]: [COMM#6454, sum#6652L, sum#6654L]
#
# (7) Exchange
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=37425]
#
# (8) HashAggregate
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Keys [1]: [COMM#6454]
# Functions [2]: [sum(POP_2010#6463L), sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum(POP_2010#6463L)#6583L, sum(HOUSING10#6460L)#6585L]
# Results [3]: [COMM#6454, sum(POP_2010#6463L)#6583L AS total_population#6584L, sum(HOUSING10#6460L)#6585L AS number_of_houses#6586L]
#
# (9) BroadcastExchange
# Input [3]: [COMM#6454, total_population#6584L, number_of_houses#6586L]
# Arguments: IdentityBroadcastMode, [plan_id=37428]
#
# (10) Scan csv
# Output [2]: [Community#6609, Estimated Median Income#6610]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string,Estimated Median Income:string>
#
# (11) Filter
# Input [2]: [Community#6609, Estimated Median Income#6610]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (12) Project
# Output [3]: [Community#6609, Estimated Median Income#6610, cast(regexp_replace(Estimated Median Income#6610, [$,], , 1) as int) AS int_income#6617]
# Input [2]: [Community#6609, Estimated Median Income#6610]
#
# (13) BroadcastNestedLoopJoin
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (14) AdaptiveSparkPlan
# Output [6]: [COMM#6454, total_population#6584L, number_of_houses#6586L, Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: isFinalPlan=false
#
#
# Broadcast Time: 11.89 seconds

# %%
# κανουμε join υπο την συνθηκη οτι το περιεχομενο του COMM του
# ενος συνολου δεδομενων να περιεχεται στην στηλη Community του
# αλλου συνολου, ετσι ωστε να εχουμε κοινες περιοχες
start_time = time.time()
df = df1.hint("merge").join(df2, df2.Community.contains(df1.COMM), "inner")
df.show()
df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Merge Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# |           COMM|total_population|number_of_houses|           Community|Estimated Median Income|int_income|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# | Toluca Terrace|            1301|             541|Los Angeles (Nort...|                $48,499|     48499|
# |Lincoln Heights|           31144|            9316|Los Angeles (Linc...|                $34,994|     34994|
# |       Van Nuys|           86019|           29170|Los Angeles (Vall...|                $50,418|     50418|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $80,890|     80890|
# |       Van Nuys|           86019|           29170|Los Angeles (Lake...|                $49,835|     49835|
# |       Van Nuys|           86019|           29170|Los Angeles (Van ...|                $45,667|     45667|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $79,028|     79028|
# |  Boyle Heights|           82627|           21548|Los Angeles (Boyl...|                $27,622|     27622|
# |  Boyle Heights|           82627|           21548|City Terrace, Los...|                $40,006|     40006|
# |  Granada Hills|           55172|           18855|Los Angeles (Gran...|                $79,680|     79680|
# |    North Hills|           56375|           16208|Los Angeles (Nort...|                $55,956|     55956|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $61,958|     61958|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $60,774|     60774|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|               $101,073|    101073|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $40,612|     40612|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $31,142|     31142|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $45,786|     45786|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $38,849|     38849|
# | Jefferson Park|            7612|            2306|Los Angeles (Jeff...|                $33,864|     33864|
# |         Encino|           42349|           18961|Los Angeles (Encino)|                $61,539|     61539|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (14)
# +- BroadcastNestedLoopJoin Inner BuildRight (13)
#    :- HashAggregate (8)
#    :  +- Exchange (7)
#    :     +- HashAggregate (6)
#    :        +- Project (5)
#    :           +- Filter (4)
#    :              +- Generate (3)
#    :                 +- Filter (2)
#    :                    +- Scan geojson  (1)
#    +- BroadcastExchange (12)
#       +- Project (11)
#          +- Filter (10)
#             +- Scan csv  (9)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6454, features#6438.properties.HOUSING10 AS HOUSING10#6460L, features#6438.properties.POP_2010 AS POP_2010#6463L]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [3]: [COMM#6454, HOUSING10#6460L, POP_2010#6463L]
# Keys [1]: [COMM#6454]
# Functions [2]: [partial_sum(POP_2010#6463L), partial_sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum#6651L, sum#6653L]
# Results [3]: [COMM#6454, sum#6652L, sum#6654L]
#
# (7) Exchange
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=37693]
#
# (8) HashAggregate
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Keys [1]: [COMM#6454]
# Functions [2]: [sum(POP_2010#6463L), sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum(POP_2010#6463L)#6583L, sum(HOUSING10#6460L)#6585L]
# Results [3]: [COMM#6454, sum(POP_2010#6463L)#6583L AS total_population#6584L, sum(HOUSING10#6460L)#6585L AS number_of_houses#6586L]
#
# (9) Scan csv
# Output [2]: [Community#6609, Estimated Median Income#6610]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string,Estimated Median Income:string>
#
# (10) Filter
# Input [2]: [Community#6609, Estimated Median Income#6610]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) Project
# Output [3]: [Community#6609, Estimated Median Income#6610, cast(regexp_replace(Estimated Median Income#6610, [$,], , 1) as int) AS int_income#6617]
# Input [2]: [Community#6609, Estimated Median Income#6610]
#
# (12) BroadcastExchange
# Input [3]: [Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: IdentityBroadcastMode, [plan_id=37696]
#
# (13) BroadcastNestedLoopJoin
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (14) AdaptiveSparkPlan
# Output [6]: [COMM#6454, total_population#6584L, number_of_houses#6586L, Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: isFinalPlan=false
#
#
# Merge Time: 10.12 seconds

# %%
# κανουμε join υπο την συνθηκη οτι το περιεχομενο του COMM του
# ενος συνολου δεδομενων να περιεχεται στην στηλη Community του
# αλλου συνολου, ετσι ωστε να εχουμε κοινες περιοχες
start_time = time.time()
df = df1.hint("shuffle_hash").join(df2, df2.Community.contains(df1.COMM), "inner")
df.show()
df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Shuffle_hash Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# |           COMM|total_population|number_of_houses|           Community|Estimated Median Income|int_income|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# | Toluca Terrace|            1301|             541|Los Angeles (Nort...|                $48,499|     48499|
# |Lincoln Heights|           31144|            9316|Los Angeles (Linc...|                $34,994|     34994|
# |       Van Nuys|           86019|           29170|Los Angeles (Vall...|                $50,418|     50418|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $80,890|     80890|
# |       Van Nuys|           86019|           29170|Los Angeles (Lake...|                $49,835|     49835|
# |       Van Nuys|           86019|           29170|Los Angeles (Van ...|                $45,667|     45667|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $79,028|     79028|
# |  Boyle Heights|           82627|           21548|Los Angeles (Boyl...|                $27,622|     27622|
# |  Boyle Heights|           82627|           21548|City Terrace, Los...|                $40,006|     40006|
# |  Granada Hills|           55172|           18855|Los Angeles (Gran...|                $79,680|     79680|
# |    North Hills|           56375|           16208|Los Angeles (Nort...|                $55,956|     55956|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $61,958|     61958|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $60,774|     60774|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|               $101,073|    101073|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $40,612|     40612|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $31,142|     31142|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $45,786|     45786|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $38,849|     38849|
# | Jefferson Park|            7612|            2306|Los Angeles (Jeff...|                $33,864|     33864|
# |         Encino|           42349|           18961|Los Angeles (Encino)|                $61,539|     61539|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (14)
# +- BroadcastNestedLoopJoin Inner BuildRight (13)
#    :- HashAggregate (8)
#    :  +- Exchange (7)
#    :     +- HashAggregate (6)
#    :        +- Project (5)
#    :           +- Filter (4)
#    :              +- Generate (3)
#    :                 +- Filter (2)
#    :                    +- Scan geojson  (1)
#    +- BroadcastExchange (12)
#       +- Project (11)
#          +- Filter (10)
#             +- Scan csv  (9)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6454, features#6438.properties.HOUSING10 AS HOUSING10#6460L, features#6438.properties.POP_2010 AS POP_2010#6463L]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [3]: [COMM#6454, HOUSING10#6460L, POP_2010#6463L]
# Keys [1]: [COMM#6454]
# Functions [2]: [partial_sum(POP_2010#6463L), partial_sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum#6651L, sum#6653L]
# Results [3]: [COMM#6454, sum#6652L, sum#6654L]
#
# (7) Exchange
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=37961]
#
# (8) HashAggregate
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Keys [1]: [COMM#6454]
# Functions [2]: [sum(POP_2010#6463L), sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum(POP_2010#6463L)#6583L, sum(HOUSING10#6460L)#6585L]
# Results [3]: [COMM#6454, sum(POP_2010#6463L)#6583L AS total_population#6584L, sum(HOUSING10#6460L)#6585L AS number_of_houses#6586L]
#
# (9) Scan csv
# Output [2]: [Community#6609, Estimated Median Income#6610]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string,Estimated Median Income:string>
#
# (10) Filter
# Input [2]: [Community#6609, Estimated Median Income#6610]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) Project
# Output [3]: [Community#6609, Estimated Median Income#6610, cast(regexp_replace(Estimated Median Income#6610, [$,], , 1) as int) AS int_income#6617]
# Input [2]: [Community#6609, Estimated Median Income#6610]
#
# (12) BroadcastExchange
# Input [3]: [Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: IdentityBroadcastMode, [plan_id=37964]
#
# (13) BroadcastNestedLoopJoin
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (14) AdaptiveSparkPlan
# Output [6]: [COMM#6454, total_population#6584L, number_of_houses#6586L, Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: isFinalPlan=false
#
#
# Shuffle_hash Time: 9.76 seconds

# %%
# κανουμε join υπο την συνθηκη οτι το περιεχομενο του COMM του
# ενος συνολου δεδομενων να περιεχεται στην στηλη Community του
# αλλου συνολου, ετσι ωστε να εχουμε κοινες περιοχες
start_time = time.time()
df = df1.hint("shuffle_replicate_nl").join(df2, df2.Community.contains(df1.COMM), "inner")
df.show()
df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Shuffle_replicate_nl Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# |           COMM|total_population|number_of_houses|           Community|Estimated Median Income|int_income|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# | Toluca Terrace|            1301|             541|Los Angeles (Nort...|                $48,499|     48499|
# |Lincoln Heights|           31144|            9316|Los Angeles (Linc...|                $34,994|     34994|
# |       Van Nuys|           86019|           29170|Los Angeles (Vall...|                $50,418|     50418|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $80,890|     80890|
# |       Van Nuys|           86019|           29170|Los Angeles (Lake...|                $49,835|     49835|
# |       Van Nuys|           86019|           29170|Los Angeles (Van ...|                $45,667|     45667|
# |       Van Nuys|           86019|           29170|Los Angeles (Sher...|                $79,028|     79028|
# |  Boyle Heights|           82627|           21548|Los Angeles (Boyl...|                $27,622|     27622|
# |  Boyle Heights|           82627|           21548|City Terrace, Los...|                $40,006|     40006|
# |  Granada Hills|           55172|           18855|Los Angeles (Gran...|                $79,680|     79680|
# |    North Hills|           56375|           16208|Los Angeles (Nort...|                $55,956|     55956|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $61,958|     61958|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|                $60,774|     60774|
# |     Northridge|           64739|           23330|Los Angeles (Nort...|               $101,073|    101073|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $40,612|     40612|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $31,142|     31142|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $45,786|     45786|
# |Wilshire Center|           47295|           19835|Los Angeles (Hanc...|                $38,849|     38849|
# | Jefferson Park|            7612|            2306|Los Angeles (Jeff...|                $33,864|     33864|
# |         Encino|           42349|           18961|Los Angeles (Encino)|                $61,539|     61539|
# +---------------+----------------+----------------+--------------------+-----------------------+----------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (13)
# +- CartesianProduct Inner (12)
#    :- HashAggregate (8)
#    :  +- Exchange (7)
#    :     +- HashAggregate (6)
#    :        +- Project (5)
#    :           +- Filter (4)
#    :              +- Generate (3)
#    :                 +- Filter (2)
#    :                    +- Scan geojson  (1)
#    +- Project (11)
#       +- Filter (10)
#          +- Scan csv  (9)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6454, features#6438.properties.HOUSING10 AS HOUSING10#6460L, features#6438.properties.POP_2010 AS POP_2010#6463L]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [3]: [COMM#6454, HOUSING10#6460L, POP_2010#6463L]
# Keys [1]: [COMM#6454]
# Functions [2]: [partial_sum(POP_2010#6463L), partial_sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum#6651L, sum#6653L]
# Results [3]: [COMM#6454, sum#6652L, sum#6654L]
#
# (7) Exchange
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=38208]
#
# (8) HashAggregate
# Input [3]: [COMM#6454, sum#6652L, sum#6654L]
# Keys [1]: [COMM#6454]
# Functions [2]: [sum(POP_2010#6463L), sum(HOUSING10#6460L)]
# Aggregate Attributes [2]: [sum(POP_2010#6463L)#6583L, sum(HOUSING10#6460L)#6585L]
# Results [3]: [COMM#6454, sum(POP_2010#6463L)#6583L AS total_population#6584L, sum(HOUSING10#6460L)#6585L AS number_of_houses#6586L]
#
# (9) Scan csv
# Output [2]: [Community#6609, Estimated Median Income#6610]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string,Estimated Median Income:string>
#
# (10) Filter
# Input [2]: [Community#6609, Estimated Median Income#6610]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) Project
# Output [3]: [Community#6609, Estimated Median Income#6610, cast(regexp_replace(Estimated Median Income#6610, [$,], , 1) as int) AS int_income#6617]
# Input [2]: [Community#6609, Estimated Median Income#6610]
#
# (12) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (13) AdaptiveSparkPlan
# Output [6]: [COMM#6454, total_population#6584L, number_of_houses#6586L, Community#6609, Estimated Median Income#6610, int_income#6617]
# Arguments: isFinalPlan=false
#
#
# Shuffle_replicate_nl Time: 9.97 seconds

# %%
df = df.select("COMM", "total_population", "number_of_houses", "int_income")
# καθως ειχαμε περισσοτερα απο ενα ZIP code για μια περιοχη, ειχαμε
# περισσοτερα απο ενα μεσα εισοδηματα ανα νοικοκυριο, επομενως σκοπος
# ειναι σε ενα dataframe να εχουμε σε μια γραμμη την περιοχη, το συνολικο
# πληθος νοικοκυριων, το συνολικο πληθυσμο και το συνολικο μεσο εισοδημα
# ανα νοικοκυριο το οποιο θα προκυψει απο τον μεσο ορο ολων των επομερους
# μεσων εισοδηματων ανα νοικοκυριων
temp_df1 = df.groupBy("COMM").agg(
    sum("int_income").alias("sum_income"),
    count("*").alias("number of ZIPs"))
temp_df2 = df.select("COMM", "total_population", "number_of_houses").distinct()
df = temp_df1.join(temp_df2, on="COMM", how="inner")
df = df.withColumn("total median income", col("sum_income") / col("number of ZIPs"))
# υπολογισμος κατα κεφαλην εισοδηματος
df = df.withColumn("income per capita",
                   round((col("total median income") * col("number_of_houses")) / col("total_population"), 3))
# σε νεα dataframes κραταμε την περιοχη και τον συνολικο πληθυσμο απο την μια
# και την περιοχη με το κατα κεφαλην εισοδημα απο την αλλη
population_df = df.select("COMM", "total_population")
capita_df = df.select("COMM", "income per capita") \
                .sort("income per capita", ascending=False)

file_1 = "s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv"
file_2 = "s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv"
# διαβαζουμε τα συνολα δεδομενων με τα εγκληματα και τα συνεννωνουμε
# σε ενα dataframe απο το οποιο βγαζουμε τις ακυρες περιπτωσεις με θυματα
# αρνητικη ηλικιας και κραταμε τις στηλες που μας ενδιαφερουν
df1 = spark.read.csv(file_1, header=True, inferSchema=True)
df2 = spark.read.csv(file_2, header=True, inferSchema=True)
df = df1.union(df2)
df = df.filter((col("Vict Age") > 0)) \
       .select("LOCATION", "Cross Street") \
       .withColumnRenamed("Cross Street", "cross_street")
# κανουμε ολους τους χαρακτηρες των περιοχων στο προηγουμενο dataframe
# κεφαλαιους για να κανουμε χρηση του contain και να βρουμε εκεινα τα
# εγκληματα που εγιναν στην αντιστοιχη περιοχη
population_df = population_df.withColumn("Locations",
                                         upper(population_df["COMM"])) \
                                .select("Locations", "total_population")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# κανουμε join με παρομοιο τροπο οπως και πριν, για να εχουμε περιοχες
# με εγκληματα, η καθε περιοχη θα εμφανιζεται οσες φορες εχει διαπραχθει
# σε αυτη καποιο εκγλημα
start_time = time.time()
crime_df = population_df.hint("broadcast").join(df, df.LOCATION.contains(population_df.Locations) | df.cross_street.contains(population_df.Locations), "inner")
crime_df.show()
crime_df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Broadcast Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+----------------+--------------------+--------------------+
# |Locations|total_population|            LOCATION|        cross_street|
# +---------+----------------+--------------------+--------------------+
# |HOLLYWOOD|           62412|CAHUENGA         ...|HOLLYWOOD        ...|
# |SAN PEDRO|           73669|8TH              ...|SAN PEDRO        ...|
# |SAN PEDRO|           73669|600 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|SAN PEDRO        ...|7TH              ...|
# |SAN PEDRO|           73669|500 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|700 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|    500 S  SAN PEDRO|                NULL|
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |SAN PEDRO|           73669|500 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|600 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|600 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|500 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|600 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|    600 S  SAN PEDRO|                NULL|
# |SAN PEDRO|           73669|500 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|600 S  SAN PEDRO ...|                NULL|
# |SAN PEDRO|           73669|           SAN PEDRO|             WINSTON|
# |SAN PEDRO|           73669|7TH              ...|           SAN PEDRO|
# |SAN PEDRO|           73669|4TH              ...|           SAN PEDRO|
# |SAN PEDRO|           73669|           SAN PEDRO|WINSTON          ...|
# +---------+----------------+--------------------+--------------------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (43)
# +- BroadcastNestedLoopJoin Inner BuildLeft (42)
#    :- BroadcastExchange (34)
#    :  +- Project (33)
#    :     +- BroadcastHashJoin Inner BuildLeft (32)
#    :        :- BroadcastExchange (16)
#    :        :  +- HashAggregate (15)
#    :        :     +- Exchange (14)
#    :        :        +- HashAggregate (13)
#    :        :           +- Project (12)
#    :        :              +- CartesianProduct Inner (11)
#    :        :                 :- HashAggregate (8)
#    :        :                 :  +- Exchange (7)
#    :        :                 :     +- HashAggregate (6)
#    :        :                 :        +- Project (5)
#    :        :                 :           +- Filter (4)
#    :        :                 :              +- Generate (3)
#    :        :                 :                 +- Filter (2)
#    :        :                 :                    +- Scan geojson  (1)
#    :        :                 +- Filter (10)
#    :        :                    +- Scan csv  (9)
#    :        +- HashAggregate (31)
#    :           +- Exchange (30)
#    :              +- HashAggregate (29)
#    :                 +- Project (28)
#    :                    +- CartesianProduct Inner (27)
#    :                       :- HashAggregate (24)
#    :                       :  +- Exchange (23)
#    :                       :     +- HashAggregate (22)
#    :                       :        +- Project (21)
#    :                       :           +- Filter (20)
#    :                       :              +- Generate (19)
#    :                       :                 +- Filter (18)
#    :                       :                    +- Scan geojson  (17)
#    :                       +- Filter (26)
#    :                          +- Scan csv  (25)
#    +- Union (41)
#       :- Project (37)
#       :  +- Filter (36)
#       :     +- Scan csv  (35)
#       +- Project (40)
#          +- Filter (39)
#             +- Scan csv  (38)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [1]: [features#6438.properties.COMM AS COMM#6454]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (7) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=39377]
#
# (8) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (9) Scan csv
# Output [1]: [Community#6609]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (10) Filter
# Input [1]: [Community#6609]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (12) Project
# Output [1]: [COMM#6454]
# Input [2]: [COMM#6454, Community#6609]
#
# (13) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (14) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=39383]
#
# (15) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (16) BroadcastExchange
# Input [1]: [COMM#6454]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=39394]
#
# (17) Scan geojson
# Output [1]: [features#6888]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (18) Filter
# Input [1]: [features#6888]
# Condition : ((size(features#6888, true) > 0) AND isnotnull(features#6888))
#
# (19) Generate
# Input [1]: [features#6888]
# Arguments: explode(features#6888), false, [features#6438]
#
# (20) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (21) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6901, features#6438.properties.HOUSING10 AS HOUSING10#6907L, features#6438.properties.POP_2010 AS POP_2010#6910L]
# Input [1]: [features#6438]
#
# (22) HashAggregate
# Input [3]: [COMM#6901, HOUSING10#6907L, POP_2010#6910L]
# Keys [1]: [COMM#6901]
# Functions [2]: [partial_sum(POP_2010#6910L), partial_sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum#7153L, sum#7155L]
# Results [3]: [COMM#6901, sum#7154L, sum#7156L]
#
# (23) Exchange
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Arguments: hashpartitioning(COMM#6901, 1000), ENSURE_REQUIREMENTS, [plan_id=39385]
#
# (24) HashAggregate
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Keys [1]: [COMM#6901]
# Functions [2]: [sum(POP_2010#6910L), sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum(POP_2010#6910L)#6583L, sum(HOUSING10#6907L)#6585L]
# Results [3]: [COMM#6901, sum(POP_2010#6910L)#6583L AS total_population#6584L, sum(HOUSING10#6907L)#6585L AS number_of_houses#6586L]
#
# (25) Scan csv
# Output [1]: [Community#6892]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (26) Filter
# Input [1]: [Community#6892]
# Condition : (isnotnull(Community#6892) AND Contains(Community#6892, Los Angeles))
#
# (27) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6892, COMM#6901)
#
# (28) Project
# Output [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Input [4]: [COMM#6901, total_population#6584L, number_of_houses#6586L, Community#6892]
#
# (29) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
#
# (30) Exchange
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Arguments: hashpartitioning(COMM#6901, total_population#6584L, number_of_houses#6586L, 1000), ENSURE_REQUIREMENTS, [plan_id=39391]
#
# (31) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [2]: [COMM#6901, total_population#6584L]
#
# (32) BroadcastHashJoin
# Left keys [1]: [COMM#6454]
# Right keys [1]: [COMM#6901]
# Join type: Inner
# Join condition: None
#
# (33) Project
# Output [2]: [upper(COMM#6454) AS Locations#7126, total_population#6584L]
# Input [3]: [COMM#6454, COMM#6901, total_population#6584L]
#
# (34) BroadcastExchange
# Input [2]: [Locations#7126, total_population#6584L]
# Arguments: IdentityBroadcastMode, [plan_id=39398]
#
# (35) Scan csv
# Output [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (36) Filter
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Condition : (isnotnull(Vict Age#6974) AND (Vict Age#6974 > 0))
#
# (37) Project
# Output [2]: [LOCATION#6987, Cross Street#6988 AS cross_street#7123]
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
#
# (38) Scan csv
# Output [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (39) Filter
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Condition : (isnotnull(Vict Age#7048) AND (Vict Age#7048 > 0))
#
# (40) Project
# Output [2]: [LOCATION#7061, Cross Street#7062 AS cross_street#7250]
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
#
# (41) Union
#
# (42) BroadcastNestedLoopJoin
# Join type: Inner
# Join condition: (Contains(LOCATION#6987, Locations#7126) OR Contains(cross_street#7123, Locations#7126))
#
# (43) AdaptiveSparkPlan
# Output [4]: [Locations#7126, total_population#6584L, LOCATION#6987, cross_street#7123]
# Arguments: isFinalPlan=false
#
#
# Broadcast Time: 16.66 seconds

# %%
# κανουμε join με παρομοιο τροπο οπως και πριν, για να εχουμε περιοχες
# με εγκληματα, η καθε περιοχη θα εμφανιζεται οσες φορες εχει διαπραχθει
# σε αυτη καποιο εκγλημα
start_time = time.time()
crime_df = population_df.hint("merge").join(df, df.LOCATION.contains(population_df.Locations) | df.cross_street.contains(population_df.Locations), "inner")
crime_df.show()
crime_df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Merge Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+----------------+--------------------+--------------------+
# |Locations|total_population|            LOCATION|        cross_street|
# +---------+----------------+--------------------+--------------------+
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|CENTRAL          ...|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|              N  6TH|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|7TH              ...|
# |  CENTRAL|           35422|                 8TH|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|      600    CENTRAL|                NULL|
# |  CENTRAL|           35422|100 N  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|400 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|                 1ST|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|CENTRAL          ...|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|             CENTRAL|
# +---------+----------------+--------------------+--------------------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (42)
# +- CartesianProduct Inner (41)
#    :- Project (33)
#    :  +- BroadcastHashJoin Inner BuildLeft (32)
#    :     :- BroadcastExchange (16)
#    :     :  +- HashAggregate (15)
#    :     :     +- Exchange (14)
#    :     :        +- HashAggregate (13)
#    :     :           +- Project (12)
#    :     :              +- CartesianProduct Inner (11)
#    :     :                 :- HashAggregate (8)
#    :     :                 :  +- Exchange (7)
#    :     :                 :     +- HashAggregate (6)
#    :     :                 :        +- Project (5)
#    :     :                 :           +- Filter (4)
#    :     :                 :              +- Generate (3)
#    :     :                 :                 +- Filter (2)
#    :     :                 :                    +- Scan geojson  (1)
#    :     :                 +- Filter (10)
#    :     :                    +- Scan csv  (9)
#    :     +- HashAggregate (31)
#    :        +- Exchange (30)
#    :           +- HashAggregate (29)
#    :              +- Project (28)
#    :                 +- CartesianProduct Inner (27)
#    :                    :- HashAggregate (24)
#    :                    :  +- Exchange (23)
#    :                    :     +- HashAggregate (22)
#    :                    :        +- Project (21)
#    :                    :           +- Filter (20)
#    :                    :              +- Generate (19)
#    :                    :                 +- Filter (18)
#    :                    :                    +- Scan geojson  (17)
#    :                    +- Filter (26)
#    :                       +- Scan csv  (25)
#    +- Union (40)
#       :- Project (36)
#       :  +- Filter (35)
#       :     +- Scan csv  (34)
#       +- Project (39)
#          +- Filter (38)
#             +- Scan csv  (37)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [1]: [features#6438.properties.COMM AS COMM#6454]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (7) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=40542]
#
# (8) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (9) Scan csv
# Output [1]: [Community#6609]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (10) Filter
# Input [1]: [Community#6609]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (12) Project
# Output [1]: [COMM#6454]
# Input [2]: [COMM#6454, Community#6609]
#
# (13) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (14) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=40548]
#
# (15) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (16) BroadcastExchange
# Input [1]: [COMM#6454]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=40559]
#
# (17) Scan geojson
# Output [1]: [features#6888]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (18) Filter
# Input [1]: [features#6888]
# Condition : ((size(features#6888, true) > 0) AND isnotnull(features#6888))
#
# (19) Generate
# Input [1]: [features#6888]
# Arguments: explode(features#6888), false, [features#6438]
#
# (20) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (21) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6901, features#6438.properties.HOUSING10 AS HOUSING10#6907L, features#6438.properties.POP_2010 AS POP_2010#6910L]
# Input [1]: [features#6438]
#
# (22) HashAggregate
# Input [3]: [COMM#6901, HOUSING10#6907L, POP_2010#6910L]
# Keys [1]: [COMM#6901]
# Functions [2]: [partial_sum(POP_2010#6910L), partial_sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum#7153L, sum#7155L]
# Results [3]: [COMM#6901, sum#7154L, sum#7156L]
#
# (23) Exchange
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Arguments: hashpartitioning(COMM#6901, 1000), ENSURE_REQUIREMENTS, [plan_id=40550]
#
# (24) HashAggregate
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Keys [1]: [COMM#6901]
# Functions [2]: [sum(POP_2010#6910L), sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum(POP_2010#6910L)#6583L, sum(HOUSING10#6907L)#6585L]
# Results [3]: [COMM#6901, sum(POP_2010#6910L)#6583L AS total_population#6584L, sum(HOUSING10#6907L)#6585L AS number_of_houses#6586L]
#
# (25) Scan csv
# Output [1]: [Community#6892]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (26) Filter
# Input [1]: [Community#6892]
# Condition : (isnotnull(Community#6892) AND Contains(Community#6892, Los Angeles))
#
# (27) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6892, COMM#6901)
#
# (28) Project
# Output [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Input [4]: [COMM#6901, total_population#6584L, number_of_houses#6586L, Community#6892]
#
# (29) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
#
# (30) Exchange
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Arguments: hashpartitioning(COMM#6901, total_population#6584L, number_of_houses#6586L, 1000), ENSURE_REQUIREMENTS, [plan_id=40556]
#
# (31) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [2]: [COMM#6901, total_population#6584L]
#
# (32) BroadcastHashJoin
# Left keys [1]: [COMM#6454]
# Right keys [1]: [COMM#6901]
# Join type: Inner
# Join condition: None
#
# (33) Project
# Output [2]: [upper(COMM#6454) AS Locations#7126, total_population#6584L]
# Input [3]: [COMM#6454, COMM#6901, total_population#6584L]
#
# (34) Scan csv
# Output [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (35) Filter
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Condition : (isnotnull(Vict Age#6974) AND (Vict Age#6974 > 0))
#
# (36) Project
# Output [2]: [LOCATION#6987, Cross Street#6988 AS cross_street#7123]
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
#
# (37) Scan csv
# Output [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (38) Filter
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Condition : (isnotnull(Vict Age#7048) AND (Vict Age#7048 > 0))
#
# (39) Project
# Output [2]: [LOCATION#7061, Cross Street#7062 AS cross_street#7371]
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
#
# (40) Union
#
# (41) CartesianProduct
# Join type: Inner
# Join condition: (Contains(LOCATION#6987, Locations#7126) OR Contains(cross_street#7123, Locations#7126))
#
# (42) AdaptiveSparkPlan
# Output [4]: [Locations#7126, total_population#6584L, LOCATION#6987, cross_street#7123]
# Arguments: isFinalPlan=false
#
#
# Merge Time: 14.78 seconds

# %%
# κανουμε join με παρομοιο τροπο οπως και πριν, για να εχουμε περιοχες
# με εγκληματα, η καθε περιοχη θα εμφανιζεται οσες φορες εχει διαπραχθει
# σε αυτη καποιο εκγλημα
start_time = time.time()
crime_df = population_df.hint("shuffle_hash").join(df, df.LOCATION.contains(population_df.Locations) | df.cross_street.contains(population_df.Locations), "inner")
crime_df.show()
crime_df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Shuffle_hash Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+----------------+--------------------+--------------------+
# |Locations|total_population|            LOCATION|        cross_street|
# +---------+----------------+--------------------+--------------------+
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|CENTRAL          ...|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|              N  6TH|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|7TH              ...|
# |  CENTRAL|           35422|                 8TH|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|      600    CENTRAL|                NULL|
# |  CENTRAL|           35422|100 N  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|400 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|                 1ST|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|CENTRAL          ...|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|             CENTRAL|
# +---------+----------------+--------------------+--------------------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (42)
# +- CartesianProduct Inner (41)
#    :- Project (33)
#    :  +- BroadcastHashJoin Inner BuildLeft (32)
#    :     :- BroadcastExchange (16)
#    :     :  +- HashAggregate (15)
#    :     :     +- Exchange (14)
#    :     :        +- HashAggregate (13)
#    :     :           +- Project (12)
#    :     :              +- CartesianProduct Inner (11)
#    :     :                 :- HashAggregate (8)
#    :     :                 :  +- Exchange (7)
#    :     :                 :     +- HashAggregate (6)
#    :     :                 :        +- Project (5)
#    :     :                 :           +- Filter (4)
#    :     :                 :              +- Generate (3)
#    :     :                 :                 +- Filter (2)
#    :     :                 :                    +- Scan geojson  (1)
#    :     :                 +- Filter (10)
#    :     :                    +- Scan csv  (9)
#    :     +- HashAggregate (31)
#    :        +- Exchange (30)
#    :           +- HashAggregate (29)
#    :              +- Project (28)
#    :                 +- CartesianProduct Inner (27)
#    :                    :- HashAggregate (24)
#    :                    :  +- Exchange (23)
#    :                    :     +- HashAggregate (22)
#    :                    :        +- Project (21)
#    :                    :           +- Filter (20)
#    :                    :              +- Generate (19)
#    :                    :                 +- Filter (18)
#    :                    :                    +- Scan geojson  (17)
#    :                    +- Filter (26)
#    :                       +- Scan csv  (25)
#    +- Union (40)
#       :- Project (36)
#       :  +- Filter (35)
#       :     +- Scan csv  (34)
#       +- Project (39)
#          +- Filter (38)
#             +- Scan csv  (37)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [1]: [features#6438.properties.COMM AS COMM#6454]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (7) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=41637]
#
# (8) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (9) Scan csv
# Output [1]: [Community#6609]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (10) Filter
# Input [1]: [Community#6609]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (12) Project
# Output [1]: [COMM#6454]
# Input [2]: [COMM#6454, Community#6609]
#
# (13) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (14) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=41643]
#
# (15) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (16) BroadcastExchange
# Input [1]: [COMM#6454]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=41654]
#
# (17) Scan geojson
# Output [1]: [features#6888]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (18) Filter
# Input [1]: [features#6888]
# Condition : ((size(features#6888, true) > 0) AND isnotnull(features#6888))
#
# (19) Generate
# Input [1]: [features#6888]
# Arguments: explode(features#6888), false, [features#6438]
#
# (20) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (21) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6901, features#6438.properties.HOUSING10 AS HOUSING10#6907L, features#6438.properties.POP_2010 AS POP_2010#6910L]
# Input [1]: [features#6438]
#
# (22) HashAggregate
# Input [3]: [COMM#6901, HOUSING10#6907L, POP_2010#6910L]
# Keys [1]: [COMM#6901]
# Functions [2]: [partial_sum(POP_2010#6910L), partial_sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum#7153L, sum#7155L]
# Results [3]: [COMM#6901, sum#7154L, sum#7156L]
#
# (23) Exchange
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Arguments: hashpartitioning(COMM#6901, 1000), ENSURE_REQUIREMENTS, [plan_id=41645]
#
# (24) HashAggregate
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Keys [1]: [COMM#6901]
# Functions [2]: [sum(POP_2010#6910L), sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum(POP_2010#6910L)#6583L, sum(HOUSING10#6907L)#6585L]
# Results [3]: [COMM#6901, sum(POP_2010#6910L)#6583L AS total_population#6584L, sum(HOUSING10#6907L)#6585L AS number_of_houses#6586L]
#
# (25) Scan csv
# Output [1]: [Community#6892]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (26) Filter
# Input [1]: [Community#6892]
# Condition : (isnotnull(Community#6892) AND Contains(Community#6892, Los Angeles))
#
# (27) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6892, COMM#6901)
#
# (28) Project
# Output [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Input [4]: [COMM#6901, total_population#6584L, number_of_houses#6586L, Community#6892]
#
# (29) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
#
# (30) Exchange
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Arguments: hashpartitioning(COMM#6901, total_population#6584L, number_of_houses#6586L, 1000), ENSURE_REQUIREMENTS, [plan_id=41651]
#
# (31) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [2]: [COMM#6901, total_population#6584L]
#
# (32) BroadcastHashJoin
# Left keys [1]: [COMM#6454]
# Right keys [1]: [COMM#6901]
# Join type: Inner
# Join condition: None
#
# (33) Project
# Output [2]: [upper(COMM#6454) AS Locations#7126, total_population#6584L]
# Input [3]: [COMM#6454, COMM#6901, total_population#6584L]
#
# (34) Scan csv
# Output [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (35) Filter
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Condition : (isnotnull(Vict Age#6974) AND (Vict Age#6974 > 0))
#
# (36) Project
# Output [2]: [LOCATION#6987, Cross Street#6988 AS cross_street#7123]
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
#
# (37) Scan csv
# Output [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (38) Filter
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Condition : (isnotnull(Vict Age#7048) AND (Vict Age#7048 > 0))
#
# (39) Project
# Output [2]: [LOCATION#7061, Cross Street#7062 AS cross_street#7492]
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
#
# (40) Union
#
# (41) CartesianProduct
# Join type: Inner
# Join condition: (Contains(LOCATION#6987, Locations#7126) OR Contains(cross_street#7123, Locations#7126))
#
# (42) AdaptiveSparkPlan
# Output [4]: [Locations#7126, total_population#6584L, LOCATION#6987, cross_street#7123]
# Arguments: isFinalPlan=false
#
#
# Shuffle_hash Time: 12.64 seconds

# %%
# κανουμε join με παρομοιο τροπο οπως και πριν, για να εχουμε περιοχες
# με εγκληματα, η καθε περιοχη θα εμφανιζεται οσες φορες εχει διαπραχθει
# σε αυτη καποιο εκγλημα
start_time = time.time()
crime_df = population_df.hint("shuffle_replicate_nl").join(df, df.LOCATION.contains(population_df.Locations) | df.cross_street.contains(population_df.Locations), "inner")
crime_df.show()
crime_df.explain(mode="formatted")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Shuffle_replicate_nl Time: {elapsed_time:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+----------------+--------------------+--------------------+
# |Locations|total_population|            LOCATION|        cross_street|
# +---------+----------------+--------------------+--------------------+
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|CENTRAL          ...|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|CENTRAL          ...|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|                 2ND|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|              N  6TH|
# |  CENTRAL|           35422|                 7TH|             CENTRAL|
# |  CENTRAL|           35422|             CENTRAL|7TH              ...|
# |  CENTRAL|           35422|                 8TH|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|      600    CENTRAL|                NULL|
# |  CENTRAL|           35422|100 N  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|400 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|                 1ST|             CENTRAL|
# |  CENTRAL|           35422|600 S  CENTRAL   ...|                NULL|
# |  CENTRAL|           35422|CENTRAL          ...|6TH              ...|
# |  CENTRAL|           35422|2ND              ...|             CENTRAL|
# +---------+----------------+--------------------+--------------------+
# only showing top 20 rows
#
# == Physical Plan ==
# AdaptiveSparkPlan (42)
# +- CartesianProduct Inner (41)
#    :- Project (33)
#    :  +- BroadcastHashJoin Inner BuildLeft (32)
#    :     :- BroadcastExchange (16)
#    :     :  +- HashAggregate (15)
#    :     :     +- Exchange (14)
#    :     :        +- HashAggregate (13)
#    :     :           +- Project (12)
#    :     :              +- CartesianProduct Inner (11)
#    :     :                 :- HashAggregate (8)
#    :     :                 :  +- Exchange (7)
#    :     :                 :     +- HashAggregate (6)
#    :     :                 :        +- Project (5)
#    :     :                 :           +- Filter (4)
#    :     :                 :              +- Generate (3)
#    :     :                 :                 +- Filter (2)
#    :     :                 :                    +- Scan geojson  (1)
#    :     :                 +- Filter (10)
#    :     :                    +- Scan csv  (9)
#    :     +- HashAggregate (31)
#    :        +- Exchange (30)
#    :           +- HashAggregate (29)
#    :              +- Project (28)
#    :                 +- CartesianProduct Inner (27)
#    :                    :- HashAggregate (24)
#    :                    :  +- Exchange (23)
#    :                    :     +- HashAggregate (22)
#    :                    :        +- Project (21)
#    :                    :           +- Filter (20)
#    :                    :              +- Generate (19)
#    :                    :                 +- Filter (18)
#    :                    :                    +- Scan geojson  (17)
#    :                    +- Filter (26)
#    :                       +- Scan csv  (25)
#    +- Union (40)
#       :- Project (36)
#       :  +- Filter (35)
#       :     +- Scan csv  (34)
#       +- Project (39)
#          +- Filter (38)
#             +- Scan csv  (37)
#
#
# (1) Scan geojson
# Output [1]: [features#6430]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#6430]
# Condition : ((size(features#6430, true) > 0) AND isnotnull(features#6430))
#
# (3) Generate
# Input [1]: [features#6430]
# Arguments: explode(features#6430), false, [features#6438]
#
# (4) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (5) Project
# Output [1]: [features#6438.properties.COMM AS COMM#6454]
# Input [1]: [features#6438]
#
# (6) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (7) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=42724]
#
# (8) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (9) Scan csv
# Output [1]: [Community#6609]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (10) Filter
# Input [1]: [Community#6609]
# Condition : (isnotnull(Community#6609) AND Contains(Community#6609, Los Angeles))
#
# (11) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6609, COMM#6454)
#
# (12) Project
# Output [1]: [COMM#6454]
# Input [2]: [COMM#6454, Community#6609]
#
# (13) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (14) Exchange
# Input [1]: [COMM#6454]
# Arguments: hashpartitioning(COMM#6454, 1000), ENSURE_REQUIREMENTS, [plan_id=42730]
#
# (15) HashAggregate
# Input [1]: [COMM#6454]
# Keys [1]: [COMM#6454]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [COMM#6454]
#
# (16) BroadcastExchange
# Input [1]: [COMM#6454]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=42741]
#
# (17) Scan geojson
# Output [1]: [features#6888]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (18) Filter
# Input [1]: [features#6888]
# Condition : ((size(features#6888, true) > 0) AND isnotnull(features#6888))
#
# (19) Generate
# Input [1]: [features#6888]
# Arguments: explode(features#6888), false, [features#6438]
#
# (20) Filter
# Input [1]: [features#6438]
# Condition : ((isnotnull(features#6438.properties.CITY) AND Contains(features#6438.properties.CITY, Los Angeles)) AND isnotnull(features#6438.properties.COMM))
#
# (21) Project
# Output [3]: [features#6438.properties.COMM AS COMM#6901, features#6438.properties.HOUSING10 AS HOUSING10#6907L, features#6438.properties.POP_2010 AS POP_2010#6910L]
# Input [1]: [features#6438]
#
# (22) HashAggregate
# Input [3]: [COMM#6901, HOUSING10#6907L, POP_2010#6910L]
# Keys [1]: [COMM#6901]
# Functions [2]: [partial_sum(POP_2010#6910L), partial_sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum#7153L, sum#7155L]
# Results [3]: [COMM#6901, sum#7154L, sum#7156L]
#
# (23) Exchange
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Arguments: hashpartitioning(COMM#6901, 1000), ENSURE_REQUIREMENTS, [plan_id=42732]
#
# (24) HashAggregate
# Input [3]: [COMM#6901, sum#7154L, sum#7156L]
# Keys [1]: [COMM#6901]
# Functions [2]: [sum(POP_2010#6910L), sum(HOUSING10#6907L)]
# Aggregate Attributes [2]: [sum(POP_2010#6910L)#6583L, sum(HOUSING10#6907L)#6585L]
# Results [3]: [COMM#6901, sum(POP_2010#6910L)#6583L AS total_population#6584L, sum(HOUSING10#6907L)#6585L AS number_of_houses#6586L]
#
# (25) Scan csv
# Output [1]: [Community#6892]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Community), StringContains(Community,Los Angeles)]
# ReadSchema: struct<Community:string>
#
# (26) Filter
# Input [1]: [Community#6892]
# Condition : (isnotnull(Community#6892) AND Contains(Community#6892, Los Angeles))
#
# (27) CartesianProduct
# Join type: Inner
# Join condition: Contains(Community#6892, COMM#6901)
#
# (28) Project
# Output [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Input [4]: [COMM#6901, total_population#6584L, number_of_houses#6586L, Community#6892]
#
# (29) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
#
# (30) Exchange
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Arguments: hashpartitioning(COMM#6901, total_population#6584L, number_of_houses#6586L, 1000), ENSURE_REQUIREMENTS, [plan_id=42738]
#
# (31) HashAggregate
# Input [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Keys [3]: [COMM#6901, total_population#6584L, number_of_houses#6586L]
# Functions: []
# Aggregate Attributes: []
# Results [2]: [COMM#6901, total_population#6584L]
#
# (32) BroadcastHashJoin
# Left keys [1]: [COMM#6454]
# Right keys [1]: [COMM#6901]
# Join type: Inner
# Join condition: None
#
# (33) Project
# Output [2]: [upper(COMM#6454) AS Locations#7126, total_population#6584L]
# Input [3]: [COMM#6454, COMM#6901, total_population#6584L]
#
# (34) Scan csv
# Output [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (35) Filter
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
# Condition : (isnotnull(Vict Age#6974) AND (Vict Age#6974 > 0))
#
# (36) Project
# Output [2]: [LOCATION#6987, Cross Street#6988 AS cross_street#7123]
# Input [3]: [Vict Age#6974, LOCATION#6987, Cross Street#6988]
#
# (37) Scan csv
# Output [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv]
# PushedFilters: [IsNotNull(Vict Age), GreaterThan(Vict Age,0)]
# ReadSchema: struct<Vict Age:int,LOCATION:string,Cross Street:string>
#
# (38) Filter
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
# Condition : (isnotnull(Vict Age#7048) AND (Vict Age#7048 > 0))
#
# (39) Project
# Output [2]: [LOCATION#7061, Cross Street#7062 AS cross_street#7613]
# Input [3]: [Vict Age#7048, LOCATION#7061, Cross Street#7062]
#
# (40) Union
#
# (41) CartesianProduct
# Join type: Inner
# Join condition: (Contains(LOCATION#6987, Locations#7126) OR Contains(cross_street#7123, Locations#7126))
#
# (42) AdaptiveSparkPlan
# Output [4]: [Locations#7126, total_population#6584L, LOCATION#6987, cross_street#7123]
# Arguments: isFinalPlan=false
#
#
# Shuffle_replicate_nl Time: 12.95 seconds

# %%
# μετραμε τον αριθμο φορων εμφανισης μιας περιοχης και στοχευουμε
# σε ενα dataframe με περιοχη - πληθυσμο - αιρθμο εγκηλματων
temp_df1 = crime_df.groupBy("Locations").agg(count("*").alias("count"))
temp_df2 = crime_df.select("Locations", "total_population").distinct()
crime_df = temp_df1.join(temp_df2, on="Locations", how="inner")
# υπολογιζουμε την αναλογια συνολικου αριθμου εγκληματων ανα ατομο
crime_df = crime_df.withColumn("crime per capita",
                               round(col("count") / col("total_population"), 4)) \
                    .select("Locations", "crime per capita") \
                    .sort("crime per capita", ascending=False)
# μετατρεπουμε παλι σε κεφαλαια για την χρηση του contain
capita_df = capita_df.withColumn("LOCATIONS", upper(capita_df["COMM"])) \
                        .select("LOCATIONS", "income per capita")
result_df = capita_df.join(crime_df, on="LOCATIONS", how="inner")
result_df.sort("income per capita", ascending=False)

result_df.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+-----------------+----------------+
# |   LOCATIONS|income per capita|crime per capita|
# +------------+-----------------+----------------+
# |SHADOW HILLS|        26640.871|          0.0034|
# |   HOLLYWOOD|        32123.914|          0.3474|
# |  CHATSWORTH|        30548.904|          0.1083|
# |      VENICE|        46048.171|          0.3877|
# |   HYDE PARK|        14137.654|          0.0322|
# | WESTCHESTER|        33241.884|          0.0142|
# | HARBOR CITY|        19581.889|          3.0E-4|
# |      SYLMAR|        16356.332|          0.0323|
# |PORTER RANCH|         35655.03|          0.0083|
# | TOLUCA LAKE|        37679.301|          0.0062|
# |    WESTLAKE|        10972.646|          0.0665|
# |     CENTRAL|         4589.135|          0.3817|
# |     MELROSE|        33511.914|          0.0937|
# |   SAN PEDRO|        27737.601|          0.2786|
# |      ENCINO|        44129.356|          0.0277|
# |   ECHO PARK|        20745.656|          0.0947|
# |   MAR VISTA|        31410.444|          0.0033|
# | PLAYA VISTA|        56217.403|          0.0528|
# |   LOS FELIZ|        29178.104|           0.127|
# |     SUNLAND|        27084.424|          0.1133|
# +------------+-----------------+----------------+
# only showing top 20 rows

# %%
# για αποθηκευση του κατα κεφαλην εισοδηματος
result_df.write \
    .option("header", "true") \
    .mode("overwrite") \
    .csv("s3://groups-bucket-dblab-905418150721/group25/query4/Income per capita/")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
